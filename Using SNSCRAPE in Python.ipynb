# %%
# Install package if necessary

# !pip install snscrape
# Out:
# Requirement already satisfied: snscrape in c:\users\rifay\anaconda3\lib\site-packages (0.4.3.20220106)
# Requirement already satisfied: lxml in c:\users\rifay\anaconda3\lib\site-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in c:\users\rifay\anaconda3\lib\site-packages (from snscrape) (3.3.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\rifay\anaconda3\lib\site-packages (from snscrape) (4.10.0)
# Requirement already satisfied: requests[socks] in c:\users\rifay\anaconda3\lib\site-packages (from snscrape) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rifay\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rifay\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rifay\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rifay\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rifay\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\rifay\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)

# %%
# Import needed packages

import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Creating an empty list to append tweet data to
twt_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('NFL since:2022-09-01 until:2022-10-09').get_items()):
    if i>3000:#number of tweets you want to scrape
        break
    twt_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username])
    
# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(twt_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
#Viewing dataframe

tweets_df
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-10-08 23:59:58+00:00  1578898026654879744
# 1    2022-10-08 23:59:57+00:00  1578898021441449984
# 2    2022-10-08 23:59:56+00:00  1578898019088732161
# 3    2022-10-08 23:59:56+00:00  1578898015309660160
# 4    2022-10-08 23:59:55+00:00  1578898013962964993
# ...                        ...                  ...
# 2996 2022-10-08 22:49:30+00:00  1578880290218729473
# 2997 2022-10-08 22:49:29+00:00  1578880289946103809
# 2998 2022-10-08 22:49:28+00:00  1578880283952435200
# 2999 2022-10-08 22:49:26+00:00  1578880277228974080
# 3000 2022-10-08 22:49:24+00:00  1578880268223811587
#
#                                                    Text         Username
# 0     dzgdzg zWWE Extreme Rules Live\n\n~🔴"FIGHT" WW...      nflncaalive
# 1                                     NUESTROS MARINERS           MauNFL
# 2     WWE Extreme Rules Live\n\n~🔴"FIGHT" WWE Extrem...      nflncaalive
# 3     @NFL So the TLDR is the Fins didn’t break any ...           Uh_naw
# 4     WWE Extreme Rules Live\n\n~🔴"FIGHT" WWE Extrem...      nflncaalive
# ...                                                 ...              ...
# 2996  @RPetaccio @RizzleDizzle21 @BenFennell_NFL @Ja...        SteveTSRA
# 2997                        @DP_NFL His burst is unreal  str8_baller2004
# 2998  O WR Tyquan Thornton se recuperou da lesão sof...      nepatriotas
# 2999  @SchomDeezy @IanAleman13 @thecheckdown Soooo? ...  HaveSomeFun1973
# 3000  Recorded the #weeklypickoff earlier today with...  Chipforthebirds
#
# [3001 rows x 4 columns]

# %%
# Creating list to append tweet data 
usr_twt_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:NBA').get_items()): #declare a username 
    if i>3000: #number of tweets you want to scrape
        break
    usr_twt_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
# Creating a dataframe from the tweets list above 
user_tweets_df = pd.DataFrame(usr_twt_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
user_tweets_df
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-10-08 21:51:38+00:00  1578865729029505029
# 1    2022-10-08 19:39:24+00:00  1578832450146689024
# 2    2022-10-08 19:28:14+00:00  1578829640570806272
# 3    2022-10-08 19:21:58+00:00  1578828065299648513
# 4    2022-10-08 19:07:34+00:00  1578824440670203904
# ...                        ...                  ...
# 2996 2022-07-08 00:36:00+00:00  1545205022283137028
# 2997 2022-07-08 00:33:05+00:00  1545204288489750528
# 2998 2022-07-08 00:27:31+00:00  1545202888888254464
# 2999 2022-07-08 00:14:50+00:00  1545199693625528321
# 3000 2022-07-08 00:11:37+00:00  1545198887115407360
#
#                                                    Text Username
# 0     An inside look at "The Nonstop NBA" - as told ...      NBA
# 1     Lindell Wigginton says his highlight of the Bu...      NBA
# 2     Trae shows love to Steve Harvey for pulling up...      NBA
# 3     De'Andre Hunter thanks the Abu Dhabi fans for ...      NBA
# 4     "This was a great experience, not only for me ...      NBA
# ...                                                 ...      ...
# 2996  Bruno Caboclo and Kofi Cockburn link up inside...      NBA
# 2997  Bruno Caboclo buckets 💪\n\nHe's got a game-hig...      NBA
# 2998  🏀🏔️ FINAL SCORE THREAD 🏔️🏀\n\nThe @sixers grab...      NBA
# 2999  The @utahjazz turn defense into offense 🔥\n\nW...      NBA
# 3000  LIVE NOW on @NBATV \n\n📺: @memgrizz vs @utahja...      NBA
#
# [3001 rows x 4 columns]
